# %% [markdown]
# <a href="https://colab.research.google.com/github/raisaurav797-svg/Workshop/blob/main/Workshop2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import pi,sin
def deg_sin():
    x = float(input("Please input a number "))
    answer = sin(pi*x/180)
    print("result = ".format(answer))
deg_sin()
# Out:
# Please input a number 4
# result =

# %%
from math import pi, sin
def deg_sin(x):
    answer = sin(pi*x/180)
    print("result = {}".format(answer))
inp = float(input("Please input a number "))
deg_sin(inp)
# Out:
# Please input a number 5
# result = 0.08715574274765817
